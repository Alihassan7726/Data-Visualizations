# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# palette=['b','g','c'] used for the colors of bars
"""car_data = car_data.dropna(subset=['modelLine'])
car_data['modelLine'] = car_data['modelLine'].replace(to_replace={'.*SE.*': 'Standard equipment'}, regex=True)
"""
# Search for this on internet when require
# Out:
# "car_data = car_data.dropna(subset=['modelLine'])\ncar_data['modelLine'] = car_data['modelLine'].replace(to_replace={'.*SE.*': 'Standard equipment'}, regex=True)\n"

# %%
Sd = pd.read_csv(r'C:\BEPEC Python Material\Student.csv')
Sd.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
Sd = Sd.rename(columns = {'race/ethnicity':'race','parental level of education':'parent edu','test preparation course':'test prep'})

# %%
Sd.head()
# Out:
#    gender     race          parent edu         lunch  test prep  math score  \
# 0  female  group B   bachelor's degree      standard       none          72
# 1  female  group C        some college      standard  completed          69
# 2  female  group B     master's degree      standard       none          90
# 3    male  group A  associate's degree  free/reduced       none          47
# 4    male  group C        some college      standard       none          76
#
#    reading score  writing score
# 0             72             74
# 1             90             88
# 2             95             93
# 3             57             44
# 4             78             75

# %%
Sd.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df = Sd.groupby(Sd['gender']).agg({'math score':'mean','reading score':'mean','writing score':'mean'})
df
# Out:
#         math score  reading score  writing score
# gender
# female   63.633205      72.608108      72.467181
# male     68.728216      65.473029      63.311203

# %%
# Females are little bit good at reading and writing , males are somewhat good at math
#plt.hist(Sd['math score'], bins = 5)
df.plot.bar()

# %%
# Scatter plot using matplotlib
Sd.columns = ['gender','race','parent edu','lunch','test prep','math score','reading score','writing score']
def scatter_plot(df , x_dim , y_dim):
    x = df[x_dim]
    y = df[y_dim]
fig , ax = plt.subplots(figsize = (12,6))
ax.scatter(Sd['math score'],Sd['reading score'] , c = 'c', marker = '+')
ax.set_title('Plot')
ax.set_xlabel('X-axis')
ax.set_xlabel
scatter_plot(Sd, 'math score' , 'reading score' )
# Removing top and right borders
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# %%
Sd['parent edu'].describe()
# Out:
# count             1000
# unique               6
# top       some college
# freq               226
# Name: parent edu, dtype: object

# %%
plt.figure(figsize = (11,5))

sns.countplot(Sd['parent edu'], palette=['b','g','c'])

# %%
sns.pairplot(Sd)

# %%
import seaborn as sns
sns.set(style="darkgrid",context = "notebook")

# Load the example dataset for Anscombe's quartet
df = sns.load_dataset("anscombe")

# Show the results of a linear regression within each dataset
sns.lmplot(x="x", y="y", col="dataset", data=df, # If we don't use 'hue' then all graphs will have same color
            ci=None, hue="dataset",palette="pastel", height=4,
           scatter_kws={"s": 50, "alpha": 1})

# %%
Sd['parent edu'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parent edu, dtype: int64

# %%
df.dataset.dtype
# Out:
# dtype('O')
