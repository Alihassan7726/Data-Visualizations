# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
# %matplotlib inline
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.nunique()
# Out:
# sepal_length    35
# sepal_width     23
# petal_length    43
# petal_width     22
# species          3
# dtype: int64

# %%
dic = {'levels':df.apply(lambda x: str(x.unique()), axis=0)}

# %%
dic
# Out:
# {'levels': sepal_length    [5.1 4.9 4.7 4.6 5.0 5.4 4.4 4.8 4.3 5.8 5.7 5...
#  sepal_width     [3.5 3.0 3.2 3.1 3.6 3.9 3.4 2.9 3.7 4.0 4.4 3...
#  petal_length    [1.4 1.3 1.5 1.7 1.6 1.1 1.2 1.0 1.9 4.7 4.5 4...
#  petal_width     [0.2 0.4 0.3 0.1 0.5 0.6 1.4 1.5 1.3 1.6 1.0 1...
#  species                       ['setosa' 'versicolor' 'virginica']
#  dtype: object}

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df[df.duplicated()]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 142           5.8          2.7           5.1          1.9  virginica

# %%
print(df.skew())
print(df.kurtosis())
# Out:
# sepal_length    0.314911
# sepal_width     0.318966
# petal_length   -0.274884
# petal_width    -0.102967
# dtype: float64
# sepal_length   -0.552064
# sepal_width     0.228249
# petal_length   -1.402103
# petal_width    -1.340604
# dtype: float64

# %%
sns.countplot(df['species']) # ye 'ggplot' style ka asar hai

# %%
plt.style.use('Solarize_Light2') 
sns.countplot(df['species'])

# %%
plt.style.use('seaborn-bright')
sns.countplot(df['species'])

# %%
help(sns.set_style)
# Out:
# Help on function set_style in module seaborn.rcmod:
#
# set_style(style=None, rc=None)
#     Set the aesthetic style of the plots.
#
#     This affects things like the color of the axes, whether a grid is
#     enabled by default, and other aesthetic elements.
#
#     Parameters
#     ----------
#     style : dict, None, or one of {darkgrid, whitegrid, dark, white, ticks}
#         A dictionary of parameters or the name of a preconfigured set.
#     rc : dict, optional
#         Parameter mappings to override the values in the preset seaborn
#         style dictionaries. This only updates parameters that are
#         considered part of the style definition.
#
#     Examples
#     --------
#     >>> set_style("whitegrid")
#
#     >>> set_style("ticks", {"xtick.major.size": 8, "ytick.major.size": 8})
#
#     See Also
#     --------
#     axes_style : return a dict of parameters or use in a ``with`` statement
#                  to temporarily set the style.
# ...

# %%
sns.set_style("whitegrid")
sns.countplot(df['species'])

# %%
sns.set_style("ticks", {"xtick.major.size": 20, "ytick.major.size": 15})
sns.countplot(df['species'])

# %%
sns.lineplot(df.sepal_length, df.sepal_width)

# %%
help(sns.color_palette)
# Out:
# Help on function color_palette in module seaborn.palettes:
#
# color_palette(palette=None, n_colors=None, desat=None)
#     Return a list of colors defining a color palette.
#
#     Available seaborn palette names:
#         deep, muted, bright, pastel, dark, colorblind
#
#     Other options:
#         name of matplotlib cmap, 'ch:<cubehelix arguments>', 'hls', 'husl',
#         or a list of colors in any format matplotlib accepts
#
#     Calling this function with ``palette=None`` will return the current
#     matplotlib color cycle.
#
#     Matplotlib palettes can be specified as reversed palettes by appending
#     "_r" to the name or as "dark" palettes by appending "_d" to the name.
#     (These options are mutually exclusive, but the resulting list of colors
#     can also be reversed).
#
#     This function can also be used in a ``with`` statement to temporarily
#     set the color cycle for a plot or set of plots.
#
# ...

# %%
sns.palplot(sns.color_palette("Set2", n_colors=7, desat=.1))
sns.countplot(df['species'])

# %%
sns.palplot(sns.color_palette())

# %%
help(sns.set_palette)
# Out:
# Help on function set_palette in module seaborn.rcmod:
#
# set_palette(palette, n_colors=None, desat=None, color_codes=False)
#     Set the matplotlib color cycle using a seaborn palette.
#
#     Parameters
#     ----------
#     palette : seaborn color paltte | matplotlib colormap | hls | husl
#         Palette definition. Should be something that :func:`color_palette`
#         can process.
#     n_colors : int
#         Number of colors in the cycle. The default number of colors will depend
#         on the format of ``palette``, see the :func:`color_palette`
#         documentation for more information.
#     desat : float
#         Proportion to desaturate each color by.
#     color_codes : bool
#         If ``True`` and ``palette`` is a seaborn palette, remap the shorthand
#         color codes (e.g. "b", "g", "r", etc.) to the colors from this palette.
#
#     Examples
#     --------
#     >>> set_palette("Reds")
#
#     >>> set_palette("Set1", 8, .75)
#
#     See Also
# ...

# %%
sns.set_palette('Accent_r', 8, .65)

# %%
import matplotlib
from matplotlib import rcParams
matplotlib.rcParams['font.size'] = 18
matplotlib.rcParams['figure.figsize'] = (9,5)

# %%
#sns.set_style('darkgrid')
sns.countplot(df['species'])

# %%
sns.countplot(df['species'])

# %%
plt.figure(figsize=(5,4))
matplotlib.rcParams['figure.facecolor'] = '#00000000'
sns.countplot(df['species'])

# %%
sns.pairplot(df, hue='species', height=3)

# %%
df.iloc[:,[0,1,2,4]]
# Out:
#      sepal_length  sepal_width  petal_length    species
# 0             5.1          3.5           1.4     setosa
# 1             4.9          3.0           1.4     setosa
# 2             4.7          3.2           1.3     setosa
# 3             4.6          3.1           1.5     setosa
# 4             5.0          3.6           1.4     setosa
# ..            ...          ...           ...        ...
# 145           6.7          3.0           5.2  virginica
# 146           6.3          2.5           5.0  virginica
# 147           6.5          3.0           5.2  virginica
# 148           6.2          3.4           5.4  virginica
# 149           5.9          3.0           5.1  virginica
#
# [150 rows x 4 columns]

# %%
sns.pairplot(df.iloc[:,[0,1,2,4]], hue='species')

# %%
import pandas as pd
import numpy as np
import seaborn as sns
df = sns.load_dataset('iris')

# %%
df[df.columns[df.dtypes =='object']]
# Out:
#        species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
#
# [150 rows x 1 columns]

# %%
df.select_dtypes('object').describe()
# Out:
#            species
# count          150
# unique           3
# top     versicolor
# freq            50

# %%
df.describe(include=object)
# Out:
#           species
# count         150
# unique          3
# top     virginica
# freq           50

# %%
df.dtypes[df.dtypes != 'object'].describe()
# Out:
# count           4
# unique          1
# top       float64
# freq            4
# dtype: object

# %%
df.dtypes[df.dtypes != 'object'].describe()
# Out:
# count           4
# unique          1
# top       float64
# freq            4
# dtype: object

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df[df.dtypes[df.dtypes != 'object'].index].describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
sns.heatmap(df.iloc[:,:3], cmap='Blues', annot=True)

# %%
sns.heatmap(df.iloc[:,:3].corr(), cmap='Blues', annot=True)

# %%
df.iloc[:,:3]
# Out:
#      sepal_length  sepal_width  petal_length
# 0             5.1          3.5           1.4
# 1             4.9          3.0           1.4
# 2             4.7          3.2           1.3
# 3             4.6          3.1           1.5
# 4             5.0          3.6           1.4
# ..            ...          ...           ...
# 145           6.7          3.0           5.2
# 146           6.3          2.5           5.0
# 147           6.5          3.0           5.2
# 148           6.2          3.4           5.4
# 149           5.9          3.0           5.1
#
# [150 rows x 3 columns]

# %% [markdown]
# # Second Part

# %%
df.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
plt.figure(figsize=(8,5))
g = sns.distplot(df['sepal_length'])
#plt.axis([0,20,0,10])
g.set(xlim=(0, 20), ylim=(0, 10)) # Alternate method
g.set_title('ffff')
g.set_xlabel('sep_len', size= 15)
# Out:
# Text(0.5, 0, 'sep_len')

# %%
x1 = [5,8,10,11]
y1 = [4,6,8,10]
x2 = [3,6,7,9,12]
y2 = [1,3,5,7,9]
sns.set(style='dark', context = 'notebook')# context = 'notebook' is responsible for bigger plot.
sns.barplot(x1,y1)
sns.barplot(x2,y2)
s = np.arange(0,5)
#plt.xlabel('fooo')
plt.xticks(ticks=s, labels=['G1','G2','G3','G4','G5'])
# Out:
# ([<matplotlib.axis.XTick at 0x269ce0ff190>,
# ...
#  [Text(0, 0, 'G1'),
#   Text(0, 0, 'G2'),
#   Text(0, 0, 'G3'),
#   Text(0, 0, 'G4'),
#   Text(0, 0, 'G5')])

# %%
x1 = [5,8,10,11]
y1 = [4,6,8,10]
x2 = [3,6,7,9,12]
y2 = [1,3,5,7,9]
#sns.set(style='dark')
plt.style.use('classic')
sns.barplot(x1,y1)
sns.barplot(x2,y2)
plt.title('fooo')
plt.legend(('age'))
